# %% [markdown]
# # TATA IPL 2025 player auction list Analysis Project

# %%
#import Libraries
import pandas as pd #used for data manipulation and analysis
import numpy as np ##used for numerical analysis
import matplotlib.pyplot as plt
import seaborn as sns #both used for data visualization

# %% [markdown]
# ## Gather data

# %%
#import csv file

df = pd.read_csv('TATAIPLAuction.csv')
df
# Out:
#      List Sr.No.  Set No. 2025 Set  First Name  Surname       Country  \
# 0              1        1       M1         Jos  Buttler       England
# 1              2        1       M1     Shreyas     Iyer         India
# 2              3        1       M1     Rishabh     Pant         India
# 3              4        1       M1      Kagiso   Rabada  South Africa
# 4              5        1       M1    Arshdeep    Singh         India
# ..           ...      ...      ...         ...      ...           ...
# 177          178       26      FA3      Nandre   Burger  South Africa
# 178          179       26      FA3     Spencer  Johnson     Australia
# 179          180       26      FA3       Umran    Malik         India
# 180          181       26      FA3  Mustafizur   Rahman    Bangladesh
# 181          182       26      FA3      Ishant   Sharma         India
#
#             DOB  Age    Specialism Batting Side          Bowling Style  \
# ...

# %% [markdown]
# ## Display top 10 rows of the dataset

# %%
df.head(10)
# Out:
#    List Sr.No.  Set No. 2025 Set First Name      Surname       Country  \
# 0            1        1       M1        Jos      Buttler       England
# 1            2        1       M1    Shreyas         Iyer         India
# 2            3        1       M1    Rishabh         Pant         India
# 3            4        1       M1     Kagiso       Rabada  South Africa
# 4            5        1       M1   Arshdeep        Singh         India
# 5            6        1       M1   Mitchell        Starc     Australia
# 6            7        2       M2  Yuzvendra       Chahal         India
# 7            8        2       M2       Liam  Livingstone       England
# 8            9        2       M2      David       Miller  South Africa
# 9           10        2       M2         KL        Rahul         India
#
#           DOB  Age    Specialism Batting Side          Bowling Style  \
# 0    8/9/1990   34  WICKETKEEPER           RHB    RIGHT ARM Off Spin
# ...

# %% [markdown]
# ##  Check last 10 rows of the dataset

# %%
df.tail(10)
# Out:
#      List Sr.No.  Set No. 2025 Set  First Name    Surname       Country  \
# 172          173       25      WK3         Ben  McDermott     Australia
# 173          174       25      WK3       Kusal     Mendis     Sri Lanka
# 174          175       25      WK3       Kusal     Perera     Sri Lanka
# 175          176       25      WK3        Josh   Philippe     Australia
# 176          177       25      WK3         Tim    Seifert   New Zealand
# 177          178       26      FA3      Nandre     Burger  South Africa
# 178          179       26      FA3     Spencer    Johnson     Australia
# 179          180       26      FA3       Umran      Malik         India
# 180          181       26      FA3  Mustafizur     Rahman    Bangladesh
# 181          182       26      FA3      Ishant     Sharma         India
#
#             DOB  Age    Specialism Batting Side        Bowling Style  \
# 172  12/12/1994   30  WICKETKEEPER           RHB  RIGHT ARM Off Spin
# ...

# %% [markdown]
# ## Check datatype of each column

# %%
df.dtypes
# Out:
# List Sr.No.                int64
# Set No.                    int64
# 2025 Set                  object
# First Name                object
# Surname                   object
# Country                   object
# DOB                       object
# Age                        int64
# Specialism                object
# Batting Side              object
# Bowling Style             object
# Test caps                float64
# ODI caps                 float64
# T20 caps                 float64
# Previous IPLTeam(s)       object
# Current IPL Team          object
# Capped or Uncapped        object
# Reserve Price Rs Lakh      int64
# dtype: object

# %% [markdown]
# ## Summary of DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   List Sr.No.            182 non-null    int64
#  1   Set No.                182 non-null    int64
#  2   2025 Set               182 non-null    object
#  3   First Name             182 non-null    object
#  4   Surname                182 non-null    object
#  5   Country                182 non-null    object
#  6   DOB                    182 non-null    object
#  7   Age                    182 non-null    int64
#  8   Specialism             182 non-null    object
#  9   Batting Side           182 non-null    object
#  10  Bowling Style          142 non-null    object
#  11  Test caps              64 non-null     float64
#  12  ODI caps               93 non-null     float64
#  13  T20 caps               104 non-null    float64
# ...

# %% [markdown]
# ## How many Rows and Columns in Dataset

# %%
df.shape
# Out:
# (182, 18)

# %% [markdown]
# ## Columns name and their length in our Dataset?

# %%
df.columns
# Out:
# Index(['List Sr.No.', 'Set No.', '2025 Set', 'First Name', 'Surname',
#        'Country', 'DOB', 'Age', 'Specialism', 'Batting Side ', 'Bowling Style',
#        'Test caps', 'ODI caps', 'T20 caps', 'Previous IPLTeam(s)',
#        'Current IPL Team', 'Capped or Uncapped', 'Reserve Price Rs Lakh'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 18

# %% [markdown]
# ## Description of Dataset

# %%
# describe() method returns description of the data in the DataFrame (i.e. count, mean, std, etc)
df.describe()
# Out:
#        List Sr.No.     Set No.         Age   Test caps    ODI caps  \
# count   182.000000  182.000000  182.000000   64.000000   93.000000
# mean     91.500000   13.714286   28.324176   32.843750   51.129032
# std      52.683014    7.406561    4.638223   33.702818   50.148741
# min       1.000000    1.000000   19.000000    1.000000    1.000000
# 25%      46.250000    8.000000   25.000000    4.000000   10.000000
# 50%      91.500000   14.000000   28.000000   21.000000   31.000000
# 75%     136.750000   20.000000   32.000000   54.750000   80.000000
# max     182.000000   26.000000   40.000000  112.000000  181.000000
#
#          T20 caps  Reserve Price Rs Lakh
# count  104.000000             182.000000
# mean    40.278846             108.021978
# std     32.743326              75.160525
# min      0.000000              30.000000
# 25%     12.000000              30.000000
# 50%     35.500000              75.000000
# 75%     63.500000             200.000000
# ...

# %% [markdown]
# # Data Cleaning and Data Prepocessing

# %% [markdown]
# ##  Check null values in dataset

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# List Sr.No.                0
# Set No.                    0
# 2025 Set                   0
# First Name                 0
# Surname                    0
# Country                    0
# DOB                        0
# Age                        0
# Specialism                 0
# Batting Side               0
# Bowling Style             40
# Test caps                118
# ODI caps                  89
# T20 caps                  78
# Previous IPLTeam(s)        0
# Current IPL Team           3
# Capped or Uncapped         0
# Reserve Price Rs Lakh      0
# dtype: int64

# %%
df['Current IPLTeam'] = df['Current IPL Team'].fillna('Unknown')

# %%
df
# Out:
#      List Sr.No.  Set No. 2025 Set  First Name  Surname       Country  \
# 0              1        1       M1         Jos  Buttler       England
# 1              2        1       M1     Shreyas     Iyer         India
# 2              3        1       M1     Rishabh     Pant         India
# 3              4        1       M1      Kagiso   Rabada  South Africa
# 4              5        1       M1    Arshdeep    Singh         India
# ..           ...      ...      ...         ...      ...           ...
# 177          178       26      FA3      Nandre   Burger  South Africa
# 178          179       26      FA3     Spencer  Johnson     Australia
# 179          180       26      FA3       Umran    Malik         India
# 180          181       26      FA3  Mustafizur   Rahman    Bangladesh
# 181          182       26      FA3      Ishant   Sharma         India
#
#             DOB  Age    Specialism Batting Side          Bowling Style  \
# ...

# %% [markdown]
# ## Group players by country and count the number of players from each country

# %%
players_by_country = df['Country'].value_counts()
print("Number of Players by Country:")
display(players_by_country)
# Out:
# Number of Players by Country:
# Country
# India           112
# England          15
# Australia        15
# South Africa     14
# New Zealand       9
# Afghanistan       6
# Sri Lanka         5
# West Indies       5
# Bangladesh        1
# Name: count, dtype: int64

# %% [markdown]
# ## How is the distribution of player's ages in the IPL Auction 2025?

# %%
plt.figure(figsize=(9, 6))
sns.histplot(df['Age'], bins=15, kde=True) #(Kernel Density Estimation)To visualize the underlying distribution of continuous variables.
plt.title('Distribution of Player Ages')
plt.xlabel('Age')
plt.ylabel('Number of Players')
plt.show()

# %% [markdown]
# ### we can observe the auction includes middle aged players

# %% [markdown]
# ## Analyze the average reserve price by specialism (role)

# %%
average_price_by_role = df.groupby('Specialism')['Reserve Price Rs Lakh'].mean().sort_values(ascending=False)
print("Average Reserve Price by Specialism:")
display(average_price_by_role)
# Out:
# Average Reserve Price by Specialism:
# Specialism
# BATTER          113.750000
# ALL-ROUNDER     112.625000
# BOWLER          107.424242
# WICKETKEEPER     97.638889
# Name: Reserve Price Rs Lakh, dtype: float64

# %% [markdown]
# ## Which player had the highest auction price (Price Rs Lakh) in the dataset?

# %%
highest_price_player = df.loc[df['Reserve Price Rs Lakh'].idxmax()]
highest_price_player
# Out:
# List Sr.No.                               1
# Set No.                                   1
# 2025 Set                                 M1
# First Name                              Jos
# Surname                             Buttler
# Country                             England
# DOB                                8/9/1990
# Age                                      34
# Specialism                     WICKETKEEPER
# Batting Side                            RHB
# Bowling Style            RIGHT ARM Off Spin
# Test caps                              57.0
# ODI caps                              181.0
# T20 caps                              124.0
# Previous IPLTeam(s)                   MI,RR
# Current IPL Team                         RR
# Capped or Uncapped                   Capped
# Reserve Price Rs Lakh                   200
# Current IPLTeam                          RR
# Name: 0, dtype: object

# %% [markdown]
# ## Which country has the most players in the IPL Auction 2025?

# %%
country_count = df['Country'].value_counts()

# %%
plt.figure(figsize=(9, 6))
country_count.plot(kind='bar', color='teal')
plt.title('Number of Players by Country in IPL Auction 2025')
plt.xlabel('Country')
plt.ylabel('Number of Players')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ### Indian Country has most player in IPL Auction 2025

# %% [markdown]
# ## Is there any correlation between the reserve price and the player's age in the IPL Auction 2025?

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Age'], df['Reserve Price Rs Lakh'], color='orange', alpha=0.7)
plt.title('Reserve Price vs Age in IPL Auction 2025')
plt.xlabel('Age')
plt.ylabel('Reserve Price (Rs Lakh)')
plt.grid(True)
plt.show()

# %% [markdown]
# ### older players are valued higher due to experience or past performances.

# %% [markdown]
# ## Who are the top 6 players with the highest reserve prices in the IPL Auction 2025?

# %%
top_6_players = df.nlargest(6, 'Reserve Price Rs Lakh')[['First Name', 'Surname', 'Reserve Price Rs Lakh']]

# %%
plt.figure(figsize=(9, 6))
plt.barh(top_6_players['First Name'] + ' ' + top_6_players['Surname'], top_6_players['Reserve Price Rs Lakh'], color='purple')
plt.title('Top 6 Players with Highest Reserve Prices in IPL Auction 2025')
plt.xlabel('Reserve Price (Rs Lakh)')
plt.ylabel('Player')
plt.show()

# %% [markdown]
# ## How many players specialize in batting, bowling, and all-rounder roles in the IPL Auction 2025?

# %%
specialism_count = df['Specialism'].value_counts()

# %%
# Plotting the distribution of players by Specialism
plt.figure(figsize=(4, 4))
plt.pie(specialism_count, labels=specialism_count.index, autopct='%1.1f%%', startangle=90, colors=['lightblue', 'lightgreen', 'lightcoral','lightpink'])
plt.title('Distribution of Players by Specialism in IPL Auction 2025')
plt.show()

# %% [markdown]
# ### 23.8 % players specialize in batting,36.2% in bowling,15.4% wicket keeping and 24.6 % all-rounder roles in the IPL Auction 2025.Bowling skill is more in demand

# %% [markdown]
# ## Which countries have the highest average reserve prices for their players in the IPL Auction 2025?

# %%
avg_reserve_by_country = df.groupby('Country')['Reserve Price Rs Lakh'].mean().nlargest(5)

# %%
plt.figure(figsize=(6, 4))
avg_reserve_by_country.plot(kind='bar', color='darkblue')
plt.title('Top 5 Countries with Highest Average Reserve Price in IPL Auction 2025')
plt.xlabel('Country')
plt.ylabel('Average Reserve Price (Rs Lakh)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### England,New Zealand,Australia,Sri Lanka,Afghanistan countries have the highest average reserve prices for their players in the IPL Auction 2025.These countrie's players are considered the most valuable in the Auction

# %% [markdown]
# ## How many capped and uncapped players are there in the IPL Auction 2025?

# %%
capped_uncapped_count = df['Capped or Uncapped'].value_counts()

# %%
plt.figure(figsize=(6, 6))
capped_uncapped_count.plot(kind='bar', color=['green', 'red'],width=0.4)
plt.title('Number of Capped vs Uncapped Players in IPL Auction 2025')
plt.xlabel('Player Type')
plt.ylabel('Number of Players')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### about 79 players already experienced in international cricket compared to those making their first appearance.

# %% [markdown]
# ## What is the distribution of players by batting side (left-handed vs right-handed)?

# %%
batting_side_count = df['Batting Side '].value_counts()
batting_side_count.plot(kind='pie', autopct='%1.1f%%', startangle=90, figsize=(4,4))
plt.title('Distribution of Players by Batting Side (Left vs Right) in IPL Auction 2025')
plt.ylabel('')
plt.show()

# %% [markdown]
#  ### We observe most of the players are Right Hand Batsman

# %%
from IPython.display import Image
Image(filename='thank you.jpg')
